# %% [markdown]
# <a href="https://colab.research.google.com/github/mflazaro/bases_ds_python/blob/main/1_desafio_datasers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **Dataset_1**

# %%
url_ds_1 = 'https://raw.githubusercontent.com/mflazaro/bases_ds_python/main/bankloans.csv'

df_st_1 = pd.read_csv(url_ds_1)

df_st_1
# Out:
#       age  ed  employ  address  income  debtinc   creddebt   othdebt  default
# 0      41   3      17       12     176      9.3  11.359392  5.008608      1.0
# 1      27   1      10        6      31     17.3   1.362202  4.000798      0.0
# 2      40   1      15       14      55      5.5   0.856075  2.168925      0.0
# 3      41   1      15       14     120      2.9   2.658720  0.821280      0.0
# 4      24   2       2        0      28     17.3   1.787436  3.056564      1.0
# ...   ...  ..     ...      ...     ...      ...        ...       ...      ...
# 1145   34   1      12       15      32      2.7   0.239328  0.624672      NaN
# 1146   32   2      12       11     116      5.7   4.026708  2.585292      NaN
# 1147   48   1      13       11      38     10.8   0.722304  3.381696      NaN
# 1148   35   2       1       11      24      7.8   0.417456  1.454544      NaN
# 1149   37   1      20       13      41     12.9   0.899130  4.389870      NaN
#
# [1150 rows x 9 columns]

# %% [markdown]
# Caracteristicas del Dataset_1:
#
# age: Age of the Customers /
# ed: Education Level /
# employ: Work Experience /
# address: Address of the Customer /
# income: Yearly Income of the customer /
# debtinc: Debt to Income Ratio /
# creddebt: Credit to Debt ratio /
# othdebt: Other debts /
# default: Customer defaulted in the past (1= defaulted, 0=Never defaulted)

# %% [markdown]
# **Dataset_2**

# %%
url_ds_2 = 'https://raw.githubusercontent.com/mflazaro/bases_ds_python/main/credit_risk_dataset.csv'

df_st_2 = pd.read_csv(url_ds_2)

df_st_2
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %% [markdown]
# Caracteristicas del Dataset_2:
#
# person_age:	Age /
# person_income:	Annual Income /
# person_home_ownership:	Home ownership /
# person_emp_length:	Employment length (in years) /
# loan_intent:	Loan intent /
# loan_grade;	Loan grade /
# loan_amnt;	Loan amount /
# loan_int_rate:	Interest rate /
# loan_status:	Loan status (0 is non default 1 is default) /
# loan_percent_income:	Percent income /
# cb_person_default_on_file:	Historical default /
# cb_preson_cred_hist_length:	Credit history length

# %% [markdown]
# **Dataset_3**

# %%
url_ds_3 = 'https://raw.githubusercontent.com/mflazaro/bases_ds_python/main/german.csv'

df_st_3 = pd.read_csv(url_ds_3, sep=';')

df_st_3
# Out:
#      Creditability  Account_Balance  Duration_of_Credit_monthly  \
# 0                1                1                          18
# 1                1                1                           9
# 2                1                2                          12
# 3                1                1                          12
# 4                1                1                          12
# ..             ...              ...                         ...
# 995              0                1                          24
# 996              0                1                          24
# 997              0                4                          21
# 998              0                2                          12
# 999              0                1                          30
#
#      Payment_Status_of_Previous_Credit  Purpose  Credit_Amount  \
# 0                                    4        2           1049
# 1                                    4        0           2799
# ...

# %% [markdown]
# Caracteristicas del Dataset_3:
#
# Account Balance: No account (1), None (No balance) (2), Some Balance (3) /
# Payment Status: Some Problems (1), Paid Up (2), No Problems (in this bank) (3) /
# Savings/Stock Value: None, Below 100 DM, [100, 1000] DM, Above 1000 DM /
# Employment Length: Below 1 year (including unemployed), [1, 4), [4, 7), Above 7 /
# Sex/Marital Status: Male Divorced/Single, Male Married/Widowed, Female /
# No of Credits at this bank: 1, More than 1 /
# Guarantor: None, Yes /
# Concurrent Credits: Other Banks or Dept Stores, None /
# ForeignWorker variable may be dropped from the study /
# Purpose of Credit: New car, Used car, Home Related, Other

# %% [markdown]
# **Dataset_4**

# %%
url_ds_4 = 'https://raw.githubusercontent.com/mflazaro/bases_ds_python/main/a_Dataset_CreditScoring.csv'

df_st_4 = pd.read_csv(url_ds_4, sep=';')

df_st_4
# Out:
#       TARGET      ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  \
# 0          1     582         3           3             0         4
# 1          1     662        15           9             0         3
# 2          1     805         0           0             0         1
# 3          1    1175         8           5             0         6
# 4          1    1373         3           1             0         9
# ...      ...     ...       ...         ...           ...       ...
# 2995       0  126441         0           0             0         2
# 2996       0  126448         0           0             0         0
# 2997       0  126465         1           1             0         8
# 2998       0  126487         4           4             0         2
# 2999       0  126503         2           1             1         0
#
#       InqTimeLast  InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  \
# 0             0.0                5          117          27  ...          3.0
# ...

# %% [markdown]
# Caracteristicas Dataset_4:
#
# TARGET: Target variable, where 0 indicates good credit and 1 indicates bad credit. /
# ID: Customer ID or unique identifier. /
# DerogCnt: Number of derogatory remarks on the customer's credit report. /
# CollectCnt: Number of collections on the customer's credit report. /
# BanruptcyInd: Indicates whether the customer has declared bankruptcy (0 for no, 1 for yes). /
# InqCnt06: Number of credit inquiries made by the customer in the last 6 months. /
# InqTimeLast: Time (in months) since the last credit inquiry. /
# InqFinanceCnt24: Number of credit inquiries related to financing in the last 24 months. /
# TLTimeFirst: Time (in months) since the first credit line was opened. /
# TLTimeLast: Time (in months) since the last credit line was opened. /
# TLBalHCPct: Percentage of total credit line balance to high credit/limit. /
# TLSatPct: Percentage of accounts where the customer's credit balance is close to the credit limit. /
# TLDel3060Cnt24: Number of accounts with late payments (30-60 days) in the last 24 months. /
# TLDel90Cnt24: Number of accounts with late payments (90+ days) in the last 24 months. /
# TLDel60CntAll: Total number of accounts with late payments (60+ days). /
# TLOpenPct: Percentage of open accounts. /
# TLBadDerogCnt: Number of accounts with bad derogatory remarks. /
# TLDel60Cnt24: Number of accounts with late payments (60+ days) in the last 24 months. /
# TLOpen24Pct: Percentage of open accounts in the last 24 months.
